# %%
from google.colab import drive
drive.mount('/content/gdrive')
import locale
locale.getpreferredencoding = lambda: "UTF-8"
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !nvidia-smi
# Out:
# Sat Apr 20 19:20:28 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla V100-SXM2-16GB           Off | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0              41W / 300W |    796MiB / 16384MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
ROOT_DIR = '/content/gdrive/My Drive/hyperpar_tuning'

# %%
# !pip install ultralytics

# %%
import os

from ultralytics import YOLO

# Load a model

model = YOLO('/content/gdrive/My Drive/hyperpar_tuning/modele z wandb/YOLOv8n_0.00033870038026958605_32_Adam/best.pt')


results = model.train(data='/content/gdrive/My Drive/hyperpar_tuning/data.yaml', epochs=300, patience = 50, fliplr = 0.0, flipud = 0.0,
                lr0 = 0.00033870038026958605, batch = 32, optimizer = 'Adam',
                momentum = 0.8117372711326822, weight_decay = 0.0007823230738041846, lrf = 0.02724522069523444)
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %%
# !scp -r /content/runs '/content/gdrive/My Drive/hyperpar_tuning'
